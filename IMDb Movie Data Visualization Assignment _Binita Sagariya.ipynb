# %%
##Importing warnings 

import warnings
warnings.filterwarnings('ignore')

# %%
## Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # <font color = blue> IMDb Movie Assignment </font>
#
#
# ## Task 1: Reading the data
#  ### Subtask 1.1: Read the Movies Data.

# %% [markdown]
# ###### Read the movies data file provided and store it in a dataframe `movies`.

# %%
movies = pd.read_csv('D:/imdb assignment/Movie+Assignment+Data.csv') ##
movies


##read_csv reads/fetch the file from source
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ###  Subtask 1.2: Inspect the Dataframe

# %% [markdown]
# #### Check the number of rows and columns in the dataframe

# %%
movies.shape  ## Counts number of rows and columns
# Out:
# (100, 62)

# %% [markdown]
# #####  Check the column-wise info of the dataframe

# %%
movies.all()  ##Checks if column-wise values all return True
# Out:
# Title             True
# title_year        True
# budget            True
# Gross             True
# actor_1_name      True
#                   ...
# Votes1000         True
# VotesUS           True
# VotesnUS          True
# content_rating    True
# Country           True
# Length: 62, dtype: bool

# %% [markdown]
# ##### Check the summary for the numeric columns

# %%
movies.describe(include = [np.number]) ##describe() used to print basic statistical data
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# ## Task 2: Data Analysis

# %% [markdown]
# ### Subtask 2.1: Reduce those Digits!

# %% [markdown]
# ###### Divide the 'gross' and 'budget' columns by 1000000 to convert  '$' to 'million $'

# %%
movies[['Gross','budget']].apply(lambda x:x/1000000)
# Out:
#          Gross  budget
# 0   151.101803    30.0
# 1   341.268248   150.0
# 2    51.738905    12.0
# 3   100.546139    47.0
# 4    47.695371     9.0
# ..         ...     ...
# 95   13.092000     3.3
# 96    8.114507     3.0
# 97  936.662225   245.0
# 98  296.347721   150.0
# 99    0.223838     5.0
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Subtask 2.2: Let's Talk Profit!

# %% [markdown]
# ##### 1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.

# %%
movies['profit']=movies['Gross'] - movies['budget']
movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ##### 2. Sort the dataframe using the `profit` column as reference using the 'sort_values' function.

# %%
movies.sort_values(by='profit',ascending=True)
# Out:
#                                          Title  title_year     budget  \
# 22                                        Hugo        2011  170000000
# 39                           The Little Prince        2015   81200000
# 17                            Edge of Tomorrow        2014  178000000
# 7                                      Tangled        2010  260000000
# 46                 Scott Pilgrim vs. the World        2010   60000000
# ..                                         ...         ...        ...
# 12                                 Toy Story 3        2010  200000000
# 32             The Hunger Games: Catching Fire        2013  130000000
# 47                                    Deadpool        2016   58000000
# 11                                The Avengers        2012  220000000
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
#
#         Gross         actor_1_name       actor_2_name           actor_3_name  \
# ...

# %% [markdown]
# ##### 3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`. Specify the rows till 10  (0-9)

# %%
top10=movies.sort_values(by=['profit'],ascending=False).head(10) # Write your code to get the top 10 profiting movies here
top10.iloc[0:10]
# Out:
#                                          Title  title_year     budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 11                                The Avengers        2012  220000000
# 47                                    Deadpool        2016   58000000
# 32             The Hunger Games: Catching Fire        2013  130000000
# 12                                 Toy Story 3        2010  200000000
# 8                        The Dark Knight Rises        2012  250000000
# 45                              The Lego Movie        2014   60000000
# 1                                     Zootopia        2016  150000000
# 41                               Despicable Me        2010   69000000
# 18                                  Inside Out        2015  175000000
#
#         Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936662225        Doug Walker         Rob Walker                      0
# ...

# %% [markdown]
# ##### 4. Plot a scatter or a joint plot between the columns `budget` and `profit` and write a few words on what you observed.\n",

# %%
plt.figure(figsize = [10,6])

p = sns.jointplot(data=movies,x='budget', y='profit',color='orange')
p.set_axis_labels('budget','profit', fontsize = 15)
plt.subplots_adjust(top=0.9)
plt.suptitle('Scatter plot of budget and profit', fontsize = 15)
plt.show()

# %% [markdown]
# The histogram on the top shows the distribution of the variable at the x-axis and the histogram to the right shows the distribution of the variable at the y-axis.
#
# #### My Observations:
#
# >Inspecting budget and profit individually, both are slightly skewed to right, which means most of the movies have positive profit and also budgets are high.
#
# >It can be observed that there are a few movies that have very high budgets but still their profits are negative.
#
# >A slightly positive trend between ‘budget’ and ‘profit’ can be observed i.e, as budget increases, profit also increases

# %% [markdown]
# ##### 5. Extract the movies with a negative profit and store them in a new dataframe - `neg_profit`"

# %%
neg_profit = movies[movies['profit']<0]
neg_profit.reset_index(drop = True)
# Out:
#                           Title  title_year     budget      Gross  \
# 0                       Tangled        2010  260000000  200807262
# 1              Edge of Tomorrow        2014  178000000  100189501
# 2                          Hugo        2011  170000000   73820094
# 3            X-Men: First Class        2011  160000000  146405371
# 4             The Little Prince        2015   81200000    1339152
# 5   Scott Pilgrim vs. the World        2010   60000000   31494270
# 6                          Rush        2013   38000000   26903709
# 7                       Warrior        2011   25000000   13651662
# 8                       Flipped        2010   14000000    1752214
# 9                         Amour        2012    8900000     225377
# 10      Tucker and Dale vs Evil        2010    5000000     223838
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 0          Brad Garrett        Donna Murphy             M.C. Gainey
# ...

# %%
neg_profit.sort_values(by='profit')[0:5]  ##Top 5 movies which has incurred losses the most
# Out:
#                           Title  title_year     budget      Gross  \
# 22                         Hugo        2011  170000000   73820094
# 39            The Little Prince        2015   81200000    1339152
# 17             Edge of Tomorrow        2014  178000000  100189501
# 7                       Tangled        2010  260000000  200807262
# 46  Scott Pilgrim vs. the World        2010   60000000   31494270
#
#            actor_1_name     actor_2_name   actor_3_name  \
# 22  ChloÃ« Grace Moretz  Christopher Lee   Ray Winstone
# 39         Jeff Bridges     James Franco  Mackenzie Foy
# 17           Tom Cruise      Lara Pulver    Noah Taylor
# 7          Brad Garrett     Donna Murphy    M.C. Gainey
# 46        Anna Kendrick    Kieran Culkin     Ellen Wong
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 22                   17000                 16000.0                  1000.0
# 39                   12000                 11000.0                  6000.0
# ...

# %% [markdown]
# ###### `Checkpoint 1:`** Can you spot the movie `Tangled` in the dataset? You may be aware of the movie 'Tangled'. Although its one of the highest grossing movies of all time, it has negative profit as per this result. If you cross check the gross values of this movie (link: https://www.imdb.com/title/tt0398286/), you can see that the gross in the dataset accounts only for the domestic gross and not the worldwide gross. This is true for may other movies also in the list."

# %% [markdown]
# ### Subtask 2.3: The General Audience and the Critics

# %% [markdown]
# ####  1. Firstly you will notice that the `MetaCritic` score is on a scale of `100` whereas the `IMDb_rating` is on a scale of 10. First convert the `MetaCritic` column to a scale of 10.

# %%
## Changing the scale of MetaCritic

movies['MetaCritic'] = movies['MetaCritic']/10

# %%
##Finding the  average ratings

movies.insert(18,column='Avg_rating',value=movies.loc[:,['MetaCritic','IMDb_rating']].mean(axis=1))

# %% [markdown]
# #### 2. Now, to find out the movies which have been liked by both critics and audiences alike and also have a high rating overall, you need to
# ####      - Create a new column `Avg_rating` which will have the average of the `MetaCritic` and `Rating` columns
# ####      - Retain only the movies in which the absolute difference(using abs() function) between the `IMDb_rating` and `Metacritic` columns is less than 0.5. Refer to this link to know how abs() funtion works - https://www.geeksforgeeks.org/abs-in-python/ .
# ####    - Sort these values in a descending order of `Avg_rating` and retain only the movies with a rating equal to higher than `8` and store these movies in a new dataframe `UniversalAcclaim`.\n",

# %%
## Sorting in descending order of average rating

movies.sort_values(by='Avg_rating',ascending = False, inplace = True)

# %%
## Find the movies with metacritic-rating < 0.5 and also with the average rating of >8.

UniversalAcclaim = movies[abs(movies['MetaCritic']-movies['IMDb_rating'])<0.5]


## Getting top 5 movies

UniversalAcclaim[(abs(movies['MetaCritic']-movies['IMDb_rating'])<0.5) & (movies['Avg_rating']>=8)].sort_index()[0:5]
# Out:
#                  Title  title_year     budget      Gross         actor_1_name  \
# 3              Arrival        2016   47000000  100546139            Amy Adams
# 33         The Martian        2015  108000000  228430993           Matt Damon
# 35    Django Unchained        2012  100000000  162804648    Leonardo DiCaprio
# 43           Gone Girl        2014   61000000  167735396        Patrick Fugit
# 93  Dallas Buyers Club        2013    5000000   27296514  Matthew McConaughey
#
#        actor_2_name       actor_3_name  actor_1_facebook_likes  \
# 3     Jeremy Renner    Forest Whitaker                   35000
# 33    Donald Glover      Benedict Wong                   13000
# 35  Christoph Waltz       Ato Essandoh                   29000
# 43        Sela Ward  Emily Ratajkowski                     835
# 93  Jennifer Garner       Denis O'Hare                   11000
#
#     actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044F Votes45A  \
# ...

# %%
UniversalAcclaim.sort_values(by= 'Avg_rating',ascending=False,inplace=True)

UniversalAcclaim.reset_index(drop=True, inplace=True)
UniversalAcclaim[0:5]
# Out:
#                                         Title  title_year     budget  \
# 0                                    Whiplash        2014    3300000
# 1                            Django Unchained        2012  100000000
# 2                          Dallas Buyers Club        2013    5000000
# 3  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 4                                     Arrival        2016   47000000
#
#        Gross         actor_1_name     actor_2_name     actor_3_name  \
# 0   13092000         J.K. Simmons  Melissa Benoist     Chris Mulkey
# 1  162804648    Leonardo DiCaprio  Christoph Waltz     Ato Essandoh
# 2   27296514  Matthew McConaughey  Jennifer Garner     Denis O'Hare
# 3  936662225          Doug Walker       Rob Walker                0
# 4  100546139            Amy Adams    Jeremy Renner  Forest Whitaker
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %% [markdown]
# ### Subtask 2.4: Find the Most Popular Trios - I

# %% [markdown]
# #### "You're a producer looking to make a blockbuster movie. There will primarily be three lead roles in your movie and you wish to cast the most popular actors for it. Now, since you don't want to take a risk, you will cast a trio which has already acted in together in a movie before. The metric that you've chosen to check the popularity is the Facebook likes of each of these actors.
#
#  >The dataframe has three columns to help you out for the same, viz. `actor_1_facebook_likes`, `actor_2_facebook_likes`, and `actor_3_facebook_likes`. Your objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of `actor_1_facebook_likes`, `actor_2_facebook_likes` and `actor_3_facebook_likes` should be maximum.
#
# >Find out the top 5 popular trios, and output their names in a list.

# %%
movies['Trio_popularity']=movies[['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']].sum(axis=1)

top = movies.filter(['actor_1_name','actor_2_name','actor_3_name','Trio_popularity'])
top = top.sort_values(by='Trio_popularity',ascending = False)
top = top.drop(labels = 'Trio_popularity',axis = 1)
top_arr = np.array(top)
top_5 = top_arr[0:5]
top_5 = top_5.tolist()
top_5
# Out:
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %% [markdown]
# ### Subtask 2.5: Find the Most Popular Trios - II

# %% [markdown]
# ####  In the previous subtask you found the popular trio based on the total number of facebook likes. Let's add a small condition to it and make sure that all three actors are popular. The condition is **none of the three actors' Facebook likes should be less than half of the other two**. For example, the following is a valid combo:\n",
#     "- actor_1_facebook_likes: 70000\n",
#     "- actor_2_facebook_likes: 40000\n",
#     "- actor_3_facebook_likes: 50000\n",
#     "\n",
#     "But the below one is not:\n",
#     "- actor_1_facebook_likes: 70000\n",
#     "- actor_2_facebook_likes: 40000\n",
#     "- actor_3_facebook_likes: 30000\n",
#     "\n",
#     "since in this case, `actor_3_facebook_likes` is 30000, which is less than half of `actor_1_facebook_likes`.\n",
#     "\n",
#     "Having this condition ensures that you aren't getting any unpopular actor in your trio (since the total likes calculated in the previous question doesn't tell anything about the individual popularities of each actor in the trio.).\n",
#     "\n",
#     "You can do a manual inspection of the top 5 popular trios you have found in the previous subtask and check how many of those trios satisfy this condition. Also, which is the most popular trio after applying the condition above?"

# %%
indiv_popularity = movies[~((((movies['actor_1_facebook_likes'] < movies['actor_2_facebook_likes']/2) | 
                             (movies['actor_1_facebook_likes'] < movies['actor_3_facebook_likes']/2))==True)
                            |(((movies['actor_2_facebook_likes'] < movies['actor_1_facebook_likes']/2) |
                              (movies['actor_2_facebook_likes'] < movies['actor_3_facebook_likes']/2))==True)
                            |(((movies['actor_3_facebook_likes'] < movies['actor_1_facebook_likes']/2) |
                              (movies['actor_2_facebook_likes'] < movies['actor_3_facebook_likes']/2))==True))]
indiv_popularity
# Out:
#                          Title  title_year     budget      Gross  \
# 94                     Boyhood        2014    4000000   25359200
# 0                   La La Land        2016   30000000  151101803
# 77                  The Artist        2011   15000000   44667095
# 87                    Nebraska        2013   12000000   17613460
# 51                        Argo        2012   44500000  136019448
# 49                   Moneyball        2011   50000000   75605492
# 27                   Inception        2010  160000000  292568851
# 8        The Dark Knight Rises        2012  250000000  448130642
# 26                Interstellar        2014  165000000  187991439
# 43                   Gone Girl        2014   61000000  167735396
# 80                  Ex Machina        2014   15000000   25440971
# 9   Captain America: Civil War        2016  250000000  407197282
# 14  X-Men: Days of Future Past        2014  200000000  233914986
# ...

# %%
top_indiv_popularity = indiv_popularity.sort_values(by = 'Trio_popularity',ascending = False)[0:5].reset_index(drop=True)

top_indiv_popularity.loc[0:5,['actor_1_name','actor_2_name','actor_3_name']].values.tolist()
# Out:
# [['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt'],
#  ['Chris Hemsworth', 'Robert Downey Jr.', 'Scarlett Johansson'],
#  ['Robert Downey Jr.', 'Scarlett Johansson', 'Chris Evans']]

# %% [markdown]
#  ### Subtask 2.6: Runtime Analysis
#
#  ####  Runtime histogram/density plot

# %%
plt.figure(figsize=[8,4])
run = sns.distplot(movies['Runtime'], color='g')
run.axes.set_title('Movies Runtime Distribution', fontsize=22)
run.set_xlabel('Runtime', fontsize=12)
plt.show()

# %% [markdown]
# ### Subtask 2.7: R-Rated Movies
#
# ####     Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, find the top 10 movies that have the highest number of votes i.e.`CVotesU18` from the `movies` dataframe. Store these in a dataframe named `PopularR`.

# %%
content_r = movies[movies['content_rating']=='R']

Popular_R = content_r.sort_values(by = 'CVotesU18', ascending = False)[0:10]

Popular_R[0:5]
# Out:
#                       Title  title_year     budget      Gross  \
# 47                 Deadpool        2016   58000000  363024263
# 36  The Wolf of Wall Street        2013  100000000  116866727
# 35         Django Unchained        2012  100000000  162804648
# 29       Mad Max: Fury Road        2015  150000000  153629485
# 95                 Whiplash        2014    3300000   13092000
#
#          actor_1_name         actor_2_name    actor_3_name  \
# 47      Ryan Reynolds            Ed Skrein  Stefan Kapicic
# 36  Leonardo DiCaprio  Matthew McConaughey     Jon Favreau
# 35  Leonardo DiCaprio      Christoph Waltz    Ato Essandoh
# 29          Tom Hardy      Charlize Theron    ZoÃ« Kravitz
# 95       J.K. Simmons      Melissa Benoist    Chris Mulkey
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 47                   16000                   805.0                   361.0
# 36                   29000                 11000.0                  4000.0
# ...

# %% [markdown]
# ## Task 3 : Demographic analysis

# %% [markdown]
#  ###  Subtask 3.1 Combine the Dataframe by Genres

# %% [markdown]
# #### 1.First, create a new dataframe df_by_genre that contains genre_1, genre_2, and genre_3 and all the columns related to CVotes/Votes from the movies data frame. There are 47 columns to be extracted in total.
#
# #### 2.Now, add a column called cnt to the dataframe df_by_genre and initialize it to one. We will realize the use of this column by the end of this analysis.
#
# #### 3.Group the dataframe df_by_genre by genre_1 and find the sum of all the numeric columns such as cnt, columns related to CVotes and Votes columns and store it in a dataframe df_by_g1
# #### Performing the same operation for genre_2 and genre_3 and store it dataframes df_by_g2 and df_by_g3 respectively

# %%
## Create Dataframe df_by_genre

column_list = []
for i in movies.columns:
    if i.startswith('CV')|i.startswith('V')| i.startswith('ge'):
        column_list.append(i)
df_by_genre = movies.loc[:, column_list]

## Create a column cnt and initialize it to 1

df_by_genre['cnt'] = 1

## Group the movies by individual genres

df_by_g1 = df_by_genre.groupby('genre_1')

df_by_g2 = df_by_genre.groupby('genre_2')

df_by_g3 = df_by_genre.groupby('genre_3')

## Finding the sum for genre_1

df_by_g1 = pd.DataFrame(df_by_g1.sum())
df_by_g2 = pd.DataFrame(df_by_g2.sum())
df_by_g3 = pd.DataFrame(df_by_g3.sum())

# %% [markdown]
# #### 5. Now that we have 3 dataframes performed by grouping over genre_1, genre_2, and genre_3 separately, it's time to combine them. For this, add the three dataframes and store it in a new dataframe df_add, so that the corresponding values of Votes/CVotes get added for each genre. There is a function called add() in pandas which lets you do this. You can refer to this link to see how this function works. Pandas add()
# #### 6. The column cnt on aggregation has basically kept the track of the number of occurrences of each genre. Subset the genres that have at least 10 movies into a new dataframe genre_top10 based on the cnt column value.

# %%
## Add the grouped data frames and store it in a new data frames

add_df1_df2 = df_by_g1.add(df_by_g2, fill_value = 0)
df_add = add_df1_df2.add(df_by_g3, fill_value = 0)

genre_top10 = df_add[df_add['cnt']>=10]

genre_top10.head()
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action     166970.0   95004.0   65573.0  171247.0  ...      240.0       239.5
# Adventure  183070.0  103318.0   69737.0  173858.0  ...      294.6       293.7
# Animation   30718.0   15733.0   10026.0   25193.0  ...       85.4        84.9
# Biography   53718.0   29510.0   20613.0   51297.0  ...      139.1       138.9
# Comedy      97469.0   56218.0   39391.0   88367.0  ...      177.4       177.4
#
# ...

# %% [markdown]
# #### 7. Now, take the mean of all the numeric columns by dividing them with the column value cnt and store it back to the same dataframe. We will be using this dataframe for further analysis in this task unless it is explicitly mentioned to use the dataframe movies
# #### 8. Since the number of votes can’t be a fraction, typecasting all the CVotes related columns to integers. Also, round off all the Votes related columns up to two digits after the decimal point.

# %%
## Extracting count column for further use

count_column = genre_top10['cnt']

## Take the mean for every column by dividing with cnt

genre_top10 = genre_top10.div(genre_top10['cnt'], axis='index')

## Rounding off the columns of Votes to two decimals

genre_top10 = genre_top10.apply(lambda x: round(x,2), axis = 0)

genre_top10.drop(columns = 'cnt', inplace = True)

# %%
## Converting CVotes to int type

col_cvotes_list = []
for i in genre_top10.columns:
    if i.startswith('CVotes'):
        col_cvotes_list.append(i)

genre_top10[col_cvotes_list] = genre_top10[col_cvotes_list].astype('int')

genre_top10.head()
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes1829F  Votes3044  \
# Action         5386      3064      2115      5524  ...        8.00       7.74
# Adventure      4817      2718      1835      4575  ...        8.09       7.75
# Animation      2792      1430       911      2290  ...        8.20       7.76
# Biography      2984      1639      1145      2849  ...        7.93       7.73
# Comedy         4237      2444      1712      3842  ...        7.95       7.71
#
# ...

# %% [markdown]
# ###  Subtask 3.2: Genre Counts!
#
# #### Make a bar chart plotting different genres vs cnt using seaborn.

# %%
## Cbinding count column to the data frame

cnt = count_column.tolist()
genre_top10['cnt'] = cnt

# %%
## Bar chart for genres vs cnt

plt.figure(figsize=[10,4])

sns.barplot(x = genre_top10.index, y = genre_top10.cnt, color = 'y')
plt.title('Different genres with their count', fontsize = 22)
plt.xlabel('genre', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %% [markdown]
# >The data set of the top 100 movies has Drama genre the most. For now, we can’t say anything about the popularity of genres simply by seeing this chart. This chart only gives the numbers and nothing else.

# %% [markdown]
# ###  Subtask 3.3: Gender and Genre

# %% [markdown]
# #### 1.We will make the first heatmap to see how the average number of votes of males is varying across the genres. Use a seaborn heatmap for this analysis. The X-axis should contain the four age-groups for males, i.e., CVotesU18M,CVotes1829M, CVotes3044M, and CVotes45AM. The Y-axis will have the genres and the annotation in the heatmap tell the average number of votes for that age-male group.
#
# #### 2.Make the second heatmap to see how the average number of votes of females is varying across the genres. Use a seaborn heatmap for this analysis. The X-axis should contain the four age-groups for females, i.e., CVotesU18F,CVotes1829F, CVotes3044F, and CVotes45AF. The Y-axis will have the genres and the annotation in the heatmap tell the average number of votes for that age-female group.

# %%
## 1st set of heat maps for CVotes-related columns

plt.figure(figsize=[30,18])

male_cvote_genre = genre_top10.groupby(genre_top10.index)['CVotesU18M','CVotes1829M','CVotes3044M','CVotes45AM'].mean()

female_cvote_genre = genre_top10.groupby(genre_top10.index)['CVotesU18F','CVotes1829F','CVotes3044F','CVotes45AF'].mean()


f,(ax1,ax2,axcb) = plt.subplots(1,3, gridspec_kw = {'width_ratios':[1,1,0.08]})

ax1.get_shared_y_axes().join(ax1,ax2)

g1 = sns.heatmap(male_cvote_genre, cmap = 'Reds', annot = True, fmt = 'd', cbar = False, ax = ax1)
g1.set_ylabel('Genres', fontsize=12)
g1.set_xlabel('Male Age Group', fontsize = 10)

g2 = sns.heatmap(female_cvote_genre, cmap = 'Greens', annot = True, fmt = 'd', cbar_ax = axcb, ax = ax2)
g2.set_ylabel(' ')
g2.set_xlabel('Female Age Group', fontsize = 10)
g2.set_yticks([])


## Rotate the ticklabels correctly (may be req)

for ax in [g1,g2]:
    t1 = ax.get_xticklabels()
    ax.set_xticklabels(t1, rotation = 90)
    tly = ax.get_yticklabels()
    ax.set_yticklabels(tly, rotation = 0)
    
plt.show()
plt.tight_layout()

# %% [markdown]
# #### Inferences from above:
#
# >Inference 1: Age ranging from 18–44 have voted the most irrespective of their gender.
#
# >Inference 2: Even if Sci-Fi has a lesser count compared to other genres (previous bar chart) still it has the highest number of votes.
#
# >Inference 3: U18M voted more than U18F. In general, movies seem to be watched less by U18 and 45A irrespective of their age or they watched but didn’t vote.
#
# >Inference 4: Females on average (ages ranging from 18 to 44) voted movies of Action, Adventure, Animation, Comedy, Romance and Thriller more (after Sci-Fi) compared to males.
#
# >Inference 5: Romance is the least voted by Male irrespective of their age compared to other genres (only the gender male), the number of votes may be higher than females but if only male gender is considered, they voted least for romance.

# %% [markdown]
# #### Repeat subtasks 1 to 4, but now instead of taking the CVotes-related columns, you need to do the same process for the Votes-related columns. These heatmaps will show you how the two genders have rated movies across various genres.\n",

# %%
## 2nd set of heat maps for Votes-related columns

male_vote_genre = genre_top10.groupby(genre_top10.index)['VotesU18M','Votes1829M','Votes3044M','Votes45AM'].mean()

female_vote_genre = genre_top10.groupby(genre_top10.index)['VotesU18F','Votes1829F','Votes3044F','Votes45AF'].mean()


f,(ax1,ax2,axcb) = plt.subplots(1,3, gridspec_kw = {'width_ratios':[1,1,0.08]})

ax1.get_shared_y_axes().join(ax1,ax2)

g1 = sns.heatmap(male_vote_genre, cmap = 'coolwarm', annot = True, cbar = False, ax = ax1)
g1.set_ylabel('Genres', fontsize=12)
g1.set_xlabel('Male Age Group', fontsize = 10)
g2 = sns.heatmap(female_vote_genre, cmap = 'coolwarm', annot = True,cbar_ax = axcb, ax = ax2)
g2.set_ylabel(' ')
g2.set_xlabel('Female Age Group', fontsize = 10)
g2.set_yticks([])


## Rotate the ticklabels correctly (may be required)

for ax in [g1,g2]:
    t1 = ax.get_xticklabels()
    ax.set_xticklabels(t1, rotation = 90)
    tly = ax.get_yticklabels()
    ax.set_yticklabels(tly, rotation = 0)
    
plt.show()
plt.tight_layout()

# %% [markdown]
# #### Inferences from above:
# >Inference 1: It is interesting to see that though the average number of votes for romance is less by male the average rating is more or less same as females, this means romance movies, in general, are watched less or voted less by males but the movies are good as they are rated well irrespective of gender especially for U18.
#
# >Inference 2: Irrespective of gender, age ranging from 30–45 have their average rating to different genres is around 7.7 to 7.8, most of them didn’t cross 8. A slight observation can be made (no causal relationship) that as your age increases you tend to become a critic.
#
# >Inference 3: We can see Animation genres has been voted steadily in Female gender, whereas in the male there is a significant difference (decrease) as age increases, It is interesting to observe that females of all age likes animation movies

# %% [markdown]
# ###  Subtask 3.4: US vs non-US Cross Analysis

# %% [markdown]
# ####  1.Creating IFUS column
# #### 2. Box plot - 1: CVotesUS(y) vs IFUS(x)

# %%
## Creating IFUS column

movies['IFUS'] = movies['Country'].apply(lambda x: 'USA' if x == 'USA' else 'non-USA')

# %%
## Box plot -1: CVotes(y)vs IFUS(x)

plt.figure(figsize = [10,10])
fig, axes = plt.subplots(nrows = 1, ncols = 2)

b1 = sns.boxplot(x = 'IFUS', y = 'CVotesUS', data = movies, orient = 'v', ax = axes[0], color='pink')
b1.axes.set_title('Dist. of Votes from USA people', fontsize = 10)
b1.set_ylabel('CVotesUS', fontsize = 12)
b1.set_xlabel('IFUS', fontsize = 12)



b2 = sns.boxplot(x = 'IFUS', y = 'CVotesnUS', data = movies, orient = 'v', ax = axes[1], color='cyan')
b2.axes.set_title('Dist. of Votes from non-USA people', fontsize = 10)
b2.set_ylabel('CVotesnUS', fontsize = 12)
b2.set_xlabel('IFUS', fontsize = 12)


plt.tight_layout()

# %% [markdown]
# Inferences from above:
#
# >Inference 1: We can observe the number of votes on average is more from non-USA people compared to USA people irrespective of the origin of the USA or non-USA movies.
#
# >Inference 2: We can observe non-USA movies the number of votes is uniformly distributed compared to USA movies.
#
# >Inference 3: We can see there is a significant difference in the number of votes from USA people for USA and non-USA movies. USA people voted less in number for non-USA movies.
#
# >Inference 4: From both the plots we can see some outliers for USA movies.
#
# >Inference 5: Overall USA movies got a greater number of votes from both USA and non-USA people compared to non-USA movies

# %% [markdown]
# #### 3.) Box plot - 2: VotesUS(y) vs IFUS(x)

# %%
plt.figure(figsize = [10,10])
fig, axes = plt.subplots(nrows = 1, ncols = 2)

b3= sns.boxplot(x = 'IFUS', y = 'VotesUS', data = movies, orient = 'v', ax = axes[0], color='green')
b3.axes.set_title('Dist. of rating from USA people', fontsize = 10)
b3.set_ylabel('VotesUS', fontsize = 12)
b3.set_xlabel('IFUS', fontsize = 12)



b4 = sns.boxplot(x = 'IFUS', y = 'VotesnUS', data = movies, orient = 'v', ax = axes[1], color='yellow')
b4.axes.set_title('Dist. of  rating from non-USA people', fontsize = 10)
b4.set_ylabel('VotesnUS', fontsize = 12)
b4.set_xlabel('IFUS', fontsize = 12)


plt.tight_layout()

# %% [markdown]
# #### Inferences:
#
# >Inference 1: On average we can see the median rating is higher (around 7.9 to 8) from USA people compared to that from non- USA people.
#
# >Inference 2: It is interesting to see that both USA and non-USA people have rated non-USA movies significantly less than that of USA movies (difference for non-USA people is greater than that of USA people).
#
# >Inference 3: Distribution of rating for non-USA movies by USA people has a uniform distribution compared to others.

# %% [markdown]
# ###  Subtask 3.5:  Top 1000 Voters Vs Genres
#
# #### 1. Sort the dataframe genre_top10 based on the value of `CVotes1000`in a descending order.
# #### 2. Make a seaborn barplot for `genre` vs `CVotes1000`.
# #### 3. Write your inferences. You can also try to relate it with the heatmaps you did in the previous subtasks.

# %%
## Sorting by CVotes1000

genre_top10_Cvotes = genre_top10.sort_values(by = 'CVotes1000', ascending = False)

# %%
## Bar plot  ---- genre vs CVotes1000

plt.figure(figsize = [10,4])

sns.barplot(x = genre_top10_Cvotes.index, y=genre_top10_Cvotes.CVotes1000, color = 'cyan')
plt.title('Top 1000 CVoters Vs Genres', fontsize = 20)
plt.xlabel('Movie genre', fontsize = 15)
plt.ylabel('CVotes1000', fontsize = 15)
# Out:
# Text(0, 0.5, 'CVotes1000')

# %% [markdown]
# #### Inferences
#
# >Sci-Fi is the most popular amongst the top 1000 Voters
#
# >The romance genre has been voted the least from the top 1000 Voters
#
# >There is not a significant difference in popularity amongst Action, Thriller and Adventure, ie these three, in general, goes hand in hand
#
# >If we compare this bar-chart with that of the previous we can see that the top 1000 IMDb voters prefer Sci-Fi over Drama and also the dataset contains movies from Drama more compared to other genres
#
# >We can see that even if Sci-Fi has very few movies in the data set (as depicted in the previous count- bar chart). In general, they got the most number of votes from Male, Female and also Top 1000 Imdb voters and also they have the highest rating across genders across their age group

# %% [markdown]
# ###  ---------------------------***********************---------------------------                                               ---------------------------***********************---------------------------

# %% [markdown]
# ###  End

# %% [markdown]
# ###  ---------------------------***********************---------------------------   ---------------------------***********************---------------------------
